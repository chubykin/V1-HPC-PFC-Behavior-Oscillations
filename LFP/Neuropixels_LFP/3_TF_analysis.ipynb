# %%
import os
import glob
import numpy as np
import pandas as pd
import pickle
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

from scipy.ndimage import gaussian_filter1d

from scipy import stats
import statsmodels.formula.api as smf

# # For TF analysis
import scipy.fftpack
from scipy.fftpack import fft, ifft
from scipy import signal

sns.set_context('poster')
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# import Python3_OpenOE_AC_map_functions_v1_08_30s as oem
import mz_LFP_functions as mz_LFP


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# for publication quality plots
def set_pub_plots(pal=sns.blend_palette(["gray","crimson", 'cyan', 'magenta', 'purple'  ],5)):
    sns.set_style("white")
    sns.set_palette(pal)
    sns.set_context("poster", font_scale=1.5, rc={"lines.linewidth": 2.5, "axes.linewidth":2.5, 'figure.facecolor': 'white'}) 
    sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
    # optional, makes markers bigger, too, axes.linewidth doesn't seem to work
    plt.rcParams['axes.linewidth'] = 2.5

rc_pub={'font.size': 25, 'axes.labelsize': 25, 'legend.fontsize': 25.0, 
    'axes.titlesize': 25, 'xtick.labelsize': 25, 'ytick.labelsize': 25, 
    #'axes.color_cycle':pal, # image.cmap - rewritesd the default colormap
    'axes.linewidth':2.5, 'lines.linewidth': 2.5,
    'xtick.color': 'black', 'ytick.color': 'black', 'axes.edgecolor': 'black','axes.labelcolor':'black','text.color':'black'}
# to restore the defaults, call plt.rcdefaults() 

#set_pub_bargraphs()
set_pub_plots()

# %%
pal=sns.blend_palette(['gray','crimson','magenta','cyan','purple'],5)
sns.palplot(pal)
sns.set_palette(pal)

# %% [markdown]
# # Load some necessary variables

# %%
insert_depth = 3100  #change this as appropriate

sp_bw_ch = 20/2

surface_ch = np.round(insert_depth/sp_bw_ch)
V1_hip_ch = np.round((insert_depth-1000)/sp_bw_ch)
Hip_thal_ch = np.round((insert_depth-1000-1200)/sp_bw_ch)

CA1_DG_ch = np.round((insert_depth-1000-600)/sp_bw_ch)

print(surface_ch, V1_hip_ch, Hip_thal_ch, CA1_DG_ch)
# Out:
# 310.0 210.0 90.0 150.0

# %%
samples_tr = 7350 #this is based on the shortest #samples in a trial
sr = 2500
n_chan = 384
rec_length = 3.0 #how long is the arduino triggered?

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # First, load in the .npy arrays and CC_ls
# These were creaded and saved using the "1_saving_LFP_arrays" jupyter notebook

# %%
all_rew_arr = np.load(r"D:\mz_Data\saved_dfs\Operant_reward\lfp_npy\1sec_all_rew.npy")
all_rew2_arr = np.load(r"D:\mz_Data\saved_dfs\Operant_reward\lfp_npy\1sec_all_rew2.npy")
all_unrew_arr = np.load(r"D:\mz_Data\saved_dfs\Operant_reward\lfp_npy\1sec_all_unrew.npy")

# %%
pkl_file = r"D:\mz_Data\saved_dfs\Operant_reward\lfp_npy\1sec_cc_ls"

open_file = open(pkl_file, "rb")
CC_ls = pickle.load(open_file)
open_file.close()

CC_ls
# Out:
# ['CC067431',
#  'CC067432',
#  'CC067432',
#  'CC067489',
#  'CC067489',
#  'CC082255',
#  'CC082255',
#  'CC082257',
#  'CC082257',
#  'CC082257',
#  'CC082260',
#  'CC082260',
#  'CC082260',
#  'CC082263',
#  'CC082263',
#  'CC082263',
#  'CC084621',
#  'CC084621']

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Time Frequency plots
# ### First, make some functions

# %%
def regroup(all_array, show=1):
    tf_groupA = []
    tf_groupB = []
    for i in range(all_array.shape[0]):
        if (CC_ls[i] == "CC082263") | (CC_ls[i] == "CC067489") | (CC_ls[i] == "CC082260") | (CC_ls[i] == "CC084621"):
            tf_groupA.append(all_array[i])
        elif (CC_ls[i] == "CC082257") | (CC_ls[i] == "CC067431") | (CC_ls[i] == "CC067432") | (CC_ls[i] == "CC082255"):
            tf_groupB.append(all_array[i])

    tf_groupA_arr = np.array(tf_groupA)
    tf_groupB_arr = np.array(tf_groupB)
    
    if show == 1:
        print(tf_groupA_arr.shape)
        print(tf_groupB_arr.shape)
    
    return tf_groupA_arr, tf_groupB_arr

# %%
def make_tf_data(group_arr):
    chs_ls = []
    for ii in range(group_arr.shape[0]):
        V1_region = group_arr[ii][200:300,:]
        min_ch = np.where(V1_region == np.amin(V1_region))
        min_ch2 = min_ch[0][0] + 199
        chs_ls.append(group_arr[ii][min_ch2,:])
        
    tf_plot = np.array(chs_ls)
    tf_plot_mean = np.mean(tf_plot, axis=0)
    tf_plot_mean = np.reshape(tf_plot_mean,(1,len(tf_plot_mean)))
    
    return tf_plot, tf_plot_mean

# %% [markdown]
# ### Second, reestablish the A and B groups
# These are 3d arrays with the following dimensions:
# mice x ch x samples

# %%
A_rew, B_rew = regroup(all_rew_arr, show=0)
A_rew2, B_rew2 = regroup(all_rew2_arr, show=0)
A_norew, B_norew = regroup(all_unrew_arr, show=0)

# %% [markdown]
# ### Third, apply the functions to find the strongest ch averaged across all mice
# This differs from a previous cell commented out because it iterates through each mouse and find the strongest channel, which is appended to a list. The mean of this list is then used to plot the TF.
#
# The important part is that the strongest channel from each mouse is used and not the overall strongest channel after averaging.
# - Previous: average all recordings, then find strongest response
# - Current: find strongest response for each mouse, then average

# %%
all_rew_tf_A, mean_rew_tf_A = make_tf_data(A_rew)
all_rew_tf_B, mean_rew_tf_B = make_tf_data(B_rew)

all_rew2_tf_A, mean_rew2_tf_A = make_tf_data(A_rew2)
all_rew2_tf_B, mean_rew2_tf_B = make_tf_data(B_rew2)

all_unrew_tf_A, mean_unrew_tf_A = make_tf_data(A_norew)
all_unrew_tf_B, mean_unrew_tf_B = make_tf_data(B_norew)

# this is just printing an example shape to make sure it worked correctly
print('Example dimension check! \nShould go from (n,7350) to (1,7350)\n')
print(all_rew_tf_A.shape)
print(mean_rew_tf_A.shape)
# Out:
# Example dimension check!
# Should go from (n,7350) to (1,7350)
#
# (10, 7350)
# (1, 7350)

# %% [markdown]
# ### Fourth, plot the individual TF heatmaps for each group
# The cell below requires a _`user input`_ for the scenario you want to look at!

# %%
rew_selection = input('Scenario (rew, rew2, unrew): ')

if rew_selection == 'rew':
    groupA_plot = mean_rew_tf_A
    groupB_plot = mean_rew_tf_B
    plt_titleA = 'WT - rew'
    plt_titleB = 'FX - rew'
    fnA = "rew_wt_heat.pdf"
    fnB = "rew_fx_heat.pdf"
elif rew_selection == 'rew2':
    groupA_plot = mean_rew2_tf_A
    groupB_plot = mean_rew2_tf_B
    plt_titleA = 'WT - rew2'
    plt_titleB = 'FX - rew2'
    fnA = "rew2_wt_heat.pdf"
    fnB = "rew2_fx_heat.pdf"
elif rew_selection == 'unrew':
    groupA_plot = mean_unrew_tf_A
    groupB_plot = mean_unrew_tf_B
    plt_titleA = 'WT - unrew'
    plt_titleB = 'FX - unrew'
    fnA = "unrew_wt_heat.pdf"
    fnB = "unrew_fx_heat.pdf"
else:
    raise Exception('Input is not one of the 3 options')

    
# f_path_start = r"D:\mz_Data\DATA_Figs\Operant_Reward\lfp\TF\2sec" #change this file destination!!
f_path_start = r"C:\Users\AChub_Lab\Desktop\mz_temp"
# Out:
# Scenario (rew, rew2, unrew): rew2

# %%
f,ax1=plt.subplots()
tf_A, time_A, frex_A, tf3d_A = mz_LFP.tf_cmw(ax=ax1, df_res=groupA_plot)

ax1.set_title(plt_titleA)
sns.despine()

# Change the end of this next line with a new file name!!
f_path = f_path_start + '\\' + fnA
plt.savefig(f_path, transparent=True)

plt.show()

# %%
f,ax1=plt.subplots()
tf_B, time_B, frex_B, tf3d_B = mz_LFP.tf_cmw(ax=ax1,df_res=groupB_plot)

ax1.set_title(plt_titleB)
sns.despine()

# Change the end of this next line with a new file name!!
f_path = f_path_start + '\\' + fnB
plt.savefig(f_path, transparent=True)

plt.show()

# %% [markdown]
# ### Fifth, rerun the TF code to extract the freq. band values
# I have to rerun it on each mouse to get the confidence intervals

# %%
rewA_df = mz_LFP.TF_band_values(all_rew_tf_A)
rewB_df = mz_LFP.TF_band_values(all_rew_tf_B)

rew2A_df = mz_LFP.TF_band_values(all_rew2_tf_A)
rew2B_df = mz_LFP.TF_band_values(all_rew2_tf_B)

unrewA_df = mz_LFP.TF_band_values(all_unrew_tf_A)
unrewB_df = mz_LFP.TF_band_values(all_unrew_tf_B)
# Out:
# 0
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 1
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 2
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 3
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 4
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 5
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 6
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 7
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 8
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 9
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 0
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 1
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 2
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 3
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 4
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 5
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 6
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 7
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 0
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 1
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 2
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 3
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 4
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 5
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 6
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 7
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 8
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 9
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 0
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 1
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 2
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 3
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 4
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 5
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 6
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 7
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 0
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 1
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 2
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 3
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 4
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 5
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 6
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 7
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 8
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 9
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 0
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 1
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 2
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 3
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 4
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 5
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 6
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )
# 7
# C:\Users\AChub_Lab\Desktop\zimmer94\Data_Analysis\LFP\mz_LFP\mz_LFP_functions.py:206: RuntimeWarning: invalid value encountered in true_divide
#   tf[methodi,fi,:] = 10*np.log10( temppow / np.mean(temppow[base_idx[0]:base_idx[1]+1]) )

# %% [markdown]
# ### Sixth, combine the two group dfs, maintaining an ID for each group

# %%
rewA_df['group'] = 'WT'
rewA_df['stim_id'] = 'rew'
rewB_df['group'] = 'FX'
rewB_df['stim_id'] = 'rew'

rew2A_df['group'] = 'WT'
rew2A_df['stim_id'] = 'rew2'
rew2B_df['group'] = 'FX'
rew2B_df['stim_id'] = 'rew2'

unrewA_df['group'] = 'WT'
unrewA_df['stim_id'] = 'unrew'
unrewB_df['group'] = 'FX'
unrewB_df['stim_id'] = 'unrew'

overall_tf = pd.concat([rewA_df, rewB_df, rew2A_df, rew2B_df, unrewA_df, unrewB_df])
overall_tf.head()
# Out:
#    id variable     value        dB group stim_id
# 2   0  12-30Hz  2.533848  4.037805    WT     rew
# 4   0  30-40Hz  4.566164  6.595515    WT     rew
# 3   0  30-70Hz  1.862491  2.700942    WT     rew
# 0   0    4-8Hz  1.573602  1.968950    WT     rew
# 5   0  50-70Hz  0.476484 -3.219513    WT     rew

# %%
print(overall_tf.group.unique())
print(overall_tf.stim_id.unique())
# Out:
# ['WT' 'FX']
# ['rew' 'rew2' 'unrew']

# %% [markdown]
# ### Seventh, plot the frequency band values
# separated out from each other by the different groups

# %%
TF_plot1 = overall_tf[overall_tf['stim_id'] == 'rew']
plt_title1 = 'Rewarded - Water'

TF_plot2 = overall_tf[overall_tf['stim_id'] == 'rew2']
plt_title2 = 'Rewarded - No Water'

TF_plot3 = overall_tf[overall_tf['stim_id'] == 'unrew']
plt_title3 = 'Unrewarded'

fn = "unrew_bar.pdf"
plt_yticks = [0,3,6,9,12]

# %%
# Plotting the barplot of the T-F plot separated by group (time window = [0.7,2.2])

g = sns.catplot(x='variable', y='value', data=TF_plot1, kind = 'bar', 
                hue='group', hue_order=['WT','FX'], palette=sns.color_palette(['cyan', 'magenta']),
                legend=False,
                height = 5, aspect=1.5,
                order=['4-8Hz', '8-12Hz', '12-30Hz', '30-40Hz','50-70Hz','30-70Hz'], 
                ci=68)

g.set_xticklabels(['4-8Hz', '8-12Hz', '12-30Hz', '30-40Hz','50-70Hz','30-70Hz'],
                           rotation=40, fontsize=20)

plt.title(plt_title1)
plt.xlabel('')
plt.yticks(plt_yticks)
plt.ylabel('Power (dB)')
plt.legend(loc="upper right")
sns.despine()

# Change the end of this next line with a new file name!!
# plt.savefig(r"U:\Data\zimmer94\Operant_Reward\lfp\TF\1sec\rew_bar.pdf", transparent=True)

plt.show()

# %%
# Plotting the barplot of the T-F plot separated by group (time window = [0.7,2.2])

g = sns.catplot(x='variable', y='value', data=TF_plot2, kind = 'bar', 
                hue='group', hue_order=['WT','FX'], palette=sns.color_palette(['cyan', 'magenta']),
                legend=False,
                height = 5, aspect=1.5,
                order=['4-8Hz', '8-12Hz', '12-30Hz', '30-40Hz','50-70Hz','30-70Hz'], 
                ci=68)

g.set_xticklabels(['4-8Hz', '8-12Hz', '12-30Hz', '30-40Hz','50-70Hz','30-70Hz'],
                           rotation=40, fontsize=20)

plt.title(plt_title2)
plt.xlabel('')
plt.yticks(plt_yticks)
plt.ylabel('Power (dB)')
plt.legend(loc="upper right")
sns.despine()

# Change the end of this next line with a new file name!!
# plt.savefig(r"U:\Data\zimmer94\Operant_Reward\lfp\TF\1sec\rew2_bar.pdf", transparent=True)

plt.show()

# %%
# Plotting the barplot of the T-F plot separated by group (time window = [0.7,2.2])

g = sns.catplot(x='variable', y='value', data=TF_plot3, kind = 'bar', 
                hue='group', hue_order=['WT','FX'], palette=sns.color_palette(['cyan', 'magenta']),
                legend=False,
                height = 5, aspect=1.5,
                order=['4-8Hz', '8-12Hz', '12-30Hz', '30-40Hz','50-70Hz','30-70Hz'], 
                ci=68)

g.set_xticklabels(['4-8Hz', '8-12Hz', '12-30Hz', '30-40Hz','50-70Hz','30-70Hz'],
                           rotation=40, fontsize=20)

plt.title(plt_title3)
plt.xlabel('')
plt.yticks(plt_yticks)
plt.ylabel('Power (dB)')
plt.legend(loc="upper right")
sns.despine()

# Change the end of this next line with a new file name!!
# plt.savefig(r"U:\Data\zimmer94\Operant_Reward\lfp\TF\1sec\unrew_bar.pdf", transparent=True)

plt.show()

# %% [markdown]
# ### Eighth, find the stats for the above plot

# %%
tf_groups = np.array(['4-8Hz','8-12Hz','12-30Hz','30-40Hz','50-70Hz','30-70Hz'])

stat_result = []
for ii in tf_groups:
    foo_A = TF_plot1[(TF_plot1['variable'] == ii) & (TF_plot1['group'] == 'WT')].value.values
    foo_B = TF_plot1[(TF_plot1['variable'] == ii) & (TF_plot1['group'] == 'FX')].value.values
    U, p = stats.mannwhitneyu(foo_A, foo_B)
    
    stat_result.append(ii)
    stat_result.append([U,p])

print(plt_title1)
stat_result
# Out:
# Rewarded - Water
# ['4-8Hz',
#  [34.0, 0.31235255792124395],
#  '8-12Hz',
#  [28.0, 0.15318750916114193],
#  '12-30Hz',
#  [23.0, 0.07110933723550159],
#  '30-40Hz',
#  [26.0, 0.11492481836862517],
#  '50-70Hz',
#  [35.0, 0.3444866523419345],
#  '30-70Hz',
#  [23.0, 0.07110933723550159]]

# %%
stat_result = []
for ii in tf_groups:
    foo_A = TF_plot2[(TF_plot2['variable'] == ii) & (TF_plot2['group'] == 'WT')].value.values
    foo_B = TF_plot2[(TF_plot2['variable'] == ii) & (TF_plot2['group'] == 'FX')].value.values
    U, p = stats.mannwhitneyu(foo_A, foo_B)
    
    stat_result.append(ii)
    stat_result.append([U,p])

print(plt_title2)
stat_result
# Out:
# Rewarded - No Water
# ['4-8Hz',
#  [13.0, 0.009211115630392893],
#  '8-12Hz',
#  [39.0, 0.4822640517031927],
#  '12-30Hz',
#  [35.0, 0.3444866523419345],
#  '30-40Hz',
#  [32.0, 0.25236011310526624],
#  '50-70Hz',
#  [38.0, 0.4469320961058073],
#  '30-70Hz',
#  [25.0, 0.09857907896428936]]

# %%
stat_result = []
for ii in tf_groups:
    foo_A = TF_plot3[(TF_plot3['variable'] == ii) & (TF_plot3['group'] == 'WT')].value.values
    foo_B = TF_plot3[(TF_plot3['variable'] == ii) & (TF_plot3['group'] == 'FX')].value.values
    U, p = stats.mannwhitneyu(foo_A, foo_B)
    
    stat_result.append(ii)
    stat_result.append([U,p])

print(plt_title3)
stat_result
# Out:
# Unrewarded
# ['4-8Hz',
#  [18.0, 0.02791888679065172],
#  '8-12Hz',
#  [22.0, 0.05979189452273125],
#  '12-30Hz',
#  [23.0, 0.07110933723550159],
#  '30-40Hz',
#  [24.0, 0.08400371915353644],
#  '50-70Hz',
#  [38.0, 0.4469320961058073],
#  '30-70Hz',
#  [23.0, 0.07110933723550159]]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
